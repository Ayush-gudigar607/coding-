# %%
#Document DataStructure

from langchain_core.documents import Document
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 #Document DataStructure
# ----> 2 code
#       3 #VSC-d841afaf
#       4 python
#
# NameError: name 'code' is not defined

# %%
from pathlib import Path

sample_text = {
    "../data/text_files/python_intro.txt": """Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and active community contribute to its popularity in various fields such as web development, data analysis, artificial intelligence, scientific computing, and more. With its simple syntax and ease of learning, Python has become a preferred choice for both beginners and experienced developers.

python is the high level interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and active community contribute to its popularity in various fields such as web development, data analysis, artificial intelligence, scientific computing, and more. With its simple syntax and ease of learning, Python has become a preferred choice for both beginners and experienced developers. it was created by guido van rossum and was first released in 1991. Python emphasizes code readability and allows developers to express concepts in fewer lines of code compared to other programming languages.

key features of python include dynamic typing, automatic memory management, and a large standard library that provides modules and functions for various tasks. Python's syntax is designed to be clean and easy to understand, making it an excellent choice for beginners in programming. Additionally, Python has a vast ecosystem of third-party libraries and frameworks that extend its capabilities, making it suitable for a wide range of applications.python widely used in web development, data science, machine learning, automation, and more.

key part of python in machine learning and data science ecosystem are libraries like numpy, pandas, matplotlib, scikit-learn, and tensorflow. these libraries provide powerful tools for data manipulation, analysis, and building machine learning models. It also encourages best practices such as using virtual environments (venv, conda), dependency management tools (pip, Poetry), linters and formatters (flake8, black), writing unit tests, and leveraging type hints for clearer, more maintainable code. The active Python community and extensive documentation make it easy to find tutorials, examples, and support for projects of any scale.
""",
    "../data/text_files/machine_learning_overview.txt": """Machine learning is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to learn from and make predictions or decisions based on data. Instead of being explicitly programmed to perform specific tasks, machine learning systems use patterns and inference to improve their performance over time as they are exposed to more data."""
}

# ensure directories exist and write files
for filepath, content in sample_text.items():
    path = Path(filepath)
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(content, encoding="utf-8")
    

print("Sample text files created.")
# Out:
# Sample text files created.

# %%
# Correct import
from langchain_community.document_loaders import TextLoader

# Usage
loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
docs = loader.load()
docs

# print(docs[0].page_content)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python is a high-level, interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and active community contribute to its popularity in various fields such as web development, data analysis, artificial intelligence, scientific computing, and more. With its simple syntax and ease of learning, Python has become a preferred choice for both beginners and experienced developers.\n\npython is the high level interpreted programming language known for its readability and versatility. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Python's extensive standard library and active community contribute to its popularity in various fields such as web development, data analysis, artificial int
# ...

# %%
###Directory Loader
from langchain_community.document_loaders import DirectoryLoader
loader = DirectoryLoader("../data/text_files/", glob="*.txt",loader_cls=TextLoader,loader_kwargs={"encoding":"utf-8"},show_progress=False)

document=loader.load()
document
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning_overview.txt'}, page_content='Machine learning is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to learn from and make predictions or decisions based on data. Instead of being explicitly programmed to perform specific tasks, machine learning systems use patterns and inference to improve their performance over time as they are exposed to more data.'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
###Directory Loader
from langchain_community.document_loaders import DirectoryLoader
Loader = DirectoryLoader("../data/pdf", glob="*.pdf",loader_cls=PyMuPDFLoader,show_progress=False)

pdf_doc=Loader.load()
pdf_doc

# for doc in pdf_doc:
#     print(doc.page_content[0:])  # Print first 500 characters of each PDF document
# Out:
# [Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'Microsoft® Word 2013', 'creationdate': '2024-11-06T19:21:45+05:30', 'source': '..\\data\\pdf\\BCS502-module-1-pdf.pdf', 'file_path': '..\\data\\pdf\\BCS502-module-1-pdf.pdf', 'total_pages': 52, 'format': 'PDF 1.7', 'title': '', 'author': 'Devaraju  B M', 'subject': '', 'keywords': '', 'moddate': '2024-12-25T17:07:00+00:00', 'trapped': '', 'modDate': 'D:20241225170700Z', 'creationDate': "D:20241106192145+05'30'", 'page': 0}, page_content='Dr. Devaraju B M  \nDept of CSE, RNSIT  \n1 \nMODULE-1: Data Communications & Networks \n \n1. DATA COMMUNICATIONS  \nData communication is the process of transferring data from one point to another using a \ncommunication system. It involves several essential components and mechanisms to ensure the \naccurate and timely delivery of data. \n1.1. Components  \nA data communication system includes the following components: \n \nFigure 1.1: A data communications 
# ...
